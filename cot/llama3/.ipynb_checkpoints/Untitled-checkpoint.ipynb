# %%
import json
import os
import sys

def clean_json(data):
    if isinstance(data, dict) and 'entities' in data:
        entities = data['entities']
        if entities and not all(key in entities[-1] for key in ['name', 'category', 'reasoning']):
            entities.pop()
        return data
    return data

# Specify the directory containing your JSON files
directory = 'llama3_generated_entity_test'

# Iterate through all JSON files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.json'):
        filepath = os.path.join(directory, filename)
        
        print(f"Processing file: {filename}")
        
        try:
            # Read the current JSON file
            with open(filepath, 'r') as file:
                data = json.load(file)
            
            # Clean the JSON data
            data = clean_json(data)
            
            if isinstance(data, list) and all('entity' in item for item in data):
                # The file is already in the desired format
                print(f"File already in correct format: {filename}")
                continue
            
            if 'entities' not in data:
                raise KeyError("'entities' key not found in the JSON file")
            
            # Transform the data structure
            new_data = []
            for entity in data['entities']:
                new_entity = {
                    'entity': entity['name'],
                    'category': entity['category'],
                    'reasoning': entity['reasoning']
                }
                new_data.append(new_entity)
            
            # Write the transformed data back to the file
            with open(filepath, 'w') as file:
                json.dump(new_data, file, indent=4)
            
            print(f"Successfully transformed: {filename}")
        except json.JSONDecodeError as e:
            print(f"JSON Decode Error in file: {filename}")
            print(f"Error message: {str(e)}")
            with open(filepath, 'r') as file:
                print(f"File content:")
                print(file.read())
            sys.exit(1)  # Stop processing immediately
        except Exception as e:
            print(f"Error processing file: {filename}")
            print(f"Error message: {str(e)}")
            print(f"File content:")
            with open(filepath, 'r') as file:
                print(file.read())
            sys.exit(1)  # Stop processing immediately

print("All JSON files have been processed successfully.")
# Out:
# Processing file: P80-1004_generated.json
# File already in correct format: P80-1004_generated.json
# Processing file: W04-2703_generated.json
# File already in correct format: W04-2703_generated.json
# Processing file: N06-4001_generated.json
# File already in correct format: N06-4001_generated.json
# Processing file: NIPS_2003_10_abs_generated.json
# File already in correct format: NIPS_2003_10_abs_generated.json
# Processing file: C04-1011_generated.json
# File already in correct format: C04-1011_generated.json
# Processing file: ECCV_2016_204_abs_generated.json
# File already in correct format: ECCV_2016_204_abs_generated.json
# Processing file: E06-1045_generated.json
# Successfully transformed: E06-1045_generated.json
# Processing file: CVPR_2010_11_abs_generated.json
# Successfully transformed: CVPR_2010_11_abs_generated.json
# Processing file: P03-1005_generated.json
# Successfully transformed: P03-1005_generated.json
# Processing file: H89-2066_generated.json
# Successfully transformed: H89-2066_generated.json
# Processing file: N03-1033_generated.json
# Successfully transformed: N03-1033_generated.json
# Processing file: CVPR_2003_18_abs_generated.json
# Successfully transformed: CVPR_2003_18_abs_generated.json
# Processing file: INTERSPEECH_2006_21_abs_generated.json
# Successfully transformed: INTERSPEECH_2006_21_abs_generated.json
# Processing file: J90-3002_generated.json
# Successfully transformed: J90-3002_generated.json
# Processing file: P03-1009_generated.json
# Successfully transformed: P03-1009_generated.json
# Processing file: H05-1095_generated.json
# Successfully transformed: H05-1095_generated.json
# Processing file: P06-4007_generated.json
# Successfully transformed: P06-4007_generated.json
# Processing file: I05-6010_generated.json
# Successfully transformed: I05-6010_generated.json
# Processing file: C88-2130_generated.json
# Successfully transformed: C88-2130_generated.json
# Processing file: C88-2162_generated.json
# Successfully transformed: C88-2162_generated.json
# Processing file: CVPR_1994_10_abs_generated.json
# Successfully transformed: CVPR_1994_10_abs_generated.json
# Processing file: P06-1018_generated.json
# Successfully transformed: P06-1018_generated.json
# Processing file: P03-1031_generated.json
# Successfully transformed: P03-1031_generated.json
# Processing file: ICML_1995_38_abs_generated.json
# Successfully transformed: ICML_1995_38_abs_generated.json
# Processing file: IJCAI_2010_5_abs_generated.json
# Successfully transformed: IJCAI_2010_5_abs_generated.json
# Processing file: A97-1028_generated.json
# Successfully transformed: A97-1028_generated.json
# Processing file: CVPR_2011_303_abs_generated.json
# Successfully transformed: CVPR_2011_303_abs_generated.json
# Processing file: CVPR_2014_11_abs_generated.json
# Successfully transformed: CVPR_2014_11_abs_generated.json
# Processing file: C90-1002_generated.json
# Successfully transformed: C90-1002_generated.json
# Processing file: E87-1043_generated.json
# Successfully transformed: E87-1043_generated.json
# Processing file: C90-2032_generated.json
# Successfully transformed: C90-2032_generated.json
# Processing file: X96-1059_generated.json
# Successfully transformed: X96-1059_generated.json
# Processing file: N03-1018_generated.json
# Successfully transformed: N03-1018_generated.json
# Processing file: INTERSPEECH_2008_21_abs_generated.json
# Successfully transformed: INTERSPEECH_2008_21_abs_generated.json
# Processing file: ICCV_2013_33_abs_generated.json
# Successfully transformed: ICCV_2013_33_abs_generated.json
# Processing file: A92-1010_generated.json
# Successfully transformed: A92-1010_generated.json
# Processing file: E89-1006_generated.json
# Successfully transformed: E89-1006_generated.json
# Processing file: CVPR_2011_10_abs_generated.json
# Error processing file: CVPR_2011_10_abs_generated.json
# Error message: 'category'
# File content:
# {
#     "entities": [
#         {
#             "name": "image sequences",
#             "category": "Material",
#             "reasoning": "This describes the data used in the research, which is a key resource or input."
#         },
#         {
#             "name": "motion trajectories",
#             "category": "Method",
#             "reasoning": "This describes a specific approach used to detect reflections in image sequences."
#         },
#         {
#             "name": "feature points",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to specific visual elements in an image."
#         },
#         {
#             "name": "reflection",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a specific phenomenon being studied in computer vision, representing a scientific concept."
#         },
#         {
#             "name": "motion estimation",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to a specific task or algorithm."
#         },
#         {
#             "name": "object recognition",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to a specific task or algorithm."
#         },
#         {
#             "name": "motion trajectories",
#             "category": "Method",
#             "reasoning": "Mentioned again in the context of analyzing these trajectories."
#         },
#         {
#             "name": "reflection",
#             "category": "OtherScientificTerm",
#             "reasoning": "Mentioned again as the specific phenomenon being detected."
#         },
#         {
#             "name": "regions",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to specific areas of interest in an image."
#         },
#         {
#             "name": "dense detection maps",
#             "category": "Method",
#             "reasoning": "This describes a specific approach used to detect reflections in image sequences."
#         },
#         {
#             "name": "rejection to pathological motion",
#             "category": "Metric",
#             "reasoning": "This is used as a measure of performance for the reflection detection technique."
#         },
#         {
#             "name": "occlusion",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to a specific phenomenon or issue."
#         },
#         {
#             "name": "image caption generation",
#             "category": "Task",
#             "reasoning": "This describes the main objective of the research, a specific scientific task."
#         },
#         {
#             "name": "unsupervised learning",
#             "category": "Method",
#             "reasoning": "This is a specific approach to solving the task, a specific algorithmic technique."
#         },
#         {
#             "name": "image features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to specific visual properties of images."
#         },
#         {
#             "name": "language models",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in natural language processing, referring to a specific algorithmic approach."
#         },
#         {
#             "name": "image caption generation",
#             "category": "Task",
#             "reasoning": "Mentioned again in the context of the previous works on this task."
#         },
#         {
#             "name": "Flickr8k dataset",
#             "category": "Material",
#             "reasoning": "This is a specific dataset or resource used in the research."
#         },
#         {
#             "name": "automatic speech recognition (ASR)",
#             "category": "Task",
#             "reasoning": "This describes the main objective of the research, a specific scientific task."
#         },
#         {
#             "name": "deep convolutional neural network (CNN)",
#             "category": "Method",
#             "reasoning": "This is a specific algorithmic approach used to solve the task."
#         },
#         {
#             "name": "acoustic features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in speech recognition, referring to specific properties of audio signals."
#         },
#         {
#             "name": "linguistic features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in natural language processing, referring to specific properties of language."
#         },
#         {
#             "name": "raw waveform",
#             "category": "Material",
#             "reasoning": "This is a specific type of input data used in the research."
#         },
#         {
#             "name": "transcribed text",
#             "category": "Material",
#             "reasoning": "This is a specific type of input data used in the research."
#         },
#         {
#             "name": "Switchboard corpus",
#             "category": "Material",
#             "reasoning": "This is a specific dataset or resource used in the research."
#         },
#         {
#             "name": "object recognition",
#             "category": "Task",
#             "reasoning": "This describes the main objective of the research, a specific scientific task."
#         },
#         {
#             "name": "image features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to specific visual properties of images."
#         },
#         {
#             "name": "linguistic properties",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in natural language processing, referring to specific properties of language."
#         },
#         {
#             "name": "joint representation",
#             "category": "Method",
#             "reasoning": "This is a specific approach used to solve the task, a specific algorithmic technique."
#         },
#         {
#             "name": "PASCAL VOC dataset",
#             "category": "Material",
#             "reasoning": "This is a specific dataset or resource used in the research."
#         },
#         {
#             "name": "convolutional neural network (CNN)",
#             "category": "Method",
#             "reasoning": "This is a specific algorithmic approach used to solve the task."
#         },
#         {
#             "name": "recurrent neural network (RNN)",
#             "category": "Method",
#             "reasoning": "This is a specific algorithmic approach used to solve the task."
#         },
#         {
#             "name": "image features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to specific visual properties of images."
#         },
#         {
#             "name": "linguistic features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in natural language processing, referring to specific properties of language."
#         },
#         {
#             "name": "joint representation",
#             "category": "Method",
#             "reasoning": "This is a specific approach used to solve the task, a specific algorithmic technique."
#         },
#         {
#             "name": "PASCAL VOC dataset",
#             "category": "Material",
#             "reasoning": "This is a specific dataset or resource used in the research."
#         },
#         {
#             "name": "object recognition",
#             "category": "Task",
#             "reasoning": "This describes the main objective of the research, a specific scientific task."
#         },
#         {
#             "name": "linguistic properties",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in natural language processing, referring to specific properties of language."
#         },
#         {
#             "name": "image features",
#             "category": "OtherScientificTerm",
#             "reasoning": "This is a concept in computer vision, referring to specific visual properties of images."
#         },
#         {
#             "name": "linguistic properties"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 33
#      30 for entity in data['entities']:
#      31     new_entity = {
#      32         'entity': entity['name'],
# ---> 33         'category': entity['category'],
#      34         'reasoning': entity['reasoning']
#      35     }
#      36     new_data.append(new_entity)
#
# KeyError: 'category'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[9], line 56
#      55                 print(file.read())
# ---> 56             sys.exit(1)  # Stop processing immediately
#      58 print("All JSON files have been processed successfully.")
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2145, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2142 if exception_only:
#    2143     stb = ['An exception has occurred, use %tb to see '
#    2144            'the full traceback.\n']
# -> 2145     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2146                                                      value))
#    2147 else:
#    2149     def contains_exceptiongroup(val):
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:1454, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1452 else:
#    1453     self.tb = etb
# -> 1454 return FormattedTB.structured_traceback(
#    1455     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1456 )
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:1345, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1342 mode = self.mode
#    1343 if mode in self.verbose_modes:
#    1344     # Verbose modes need a full traceback
# -> 1345     return VerboseTB.structured_traceback(
#    1346         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1347     )
#    1348 elif mode == 'Minimal':
#    1349     return ListTB.get_exception_only(self, etype, value)
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:1192, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1183 def structured_traceback(
#    1184     self,
#    1185     etype: type,
#    (...)
#    1189     number_of_lines_of_context: int = 5,
#    1190 ):
#    1191     """Return a nice text document describing the traceback."""
# -> 1192     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                            tb_offset)
#    1195     colors = self.Colors  # just a shorthand + quicker name lookup
#    1196     colorsnormal = colors.Normal  # used a lot
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:1082, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1079 assert isinstance(tb_offset, int)
#    1080 head = self.prepare_header(str(etype), self.long_header)
#    1081 records = (
# -> 1082     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1083 )
#    1085 frames = []
#    1086 skipped = 0
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/ultratb.py:1150, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1148 while cf is not None:
#    1149     try:
# -> 1150         mod = inspect.getmodule(cf.tb_frame)
#    1151         if mod is not None:
#    1152             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
